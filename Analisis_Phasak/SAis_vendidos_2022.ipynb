# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
# pd.set_option('max_columns', 200)

# %%
df = pd.read_csv('Sais_vendidos_2020.csv', sep=';', encoding='latin')

# %%
df.dtypes
# Out:
# Referencia            object
# Cantidad con signo     int64
# Entradas               int64
# Salidas                int64
# Cantidad Abonada       int64
# Precio                object
# Importe               object
# Existencia             int64
# Precio medio          object
# Escalón de precio      int64
# Codigo Cliente         int64
# Codigo Factura        object
# Fecha Factura         object
# Serie Factura          int64
# Codigo Comercial       int64
# Empresa Emisora        int64
# Nombre Tarifa         object
# dtype: object

# %%
def impcsv():
    df['Precio'] = df['Precio'].str.replace(',','.')
    df['Importe'] = df['Importe'].str.replace(',','.')
    df['Precio medio'] = df['Precio medio'].str.replace(',','.')
    df['Precio'] = df['Precio'].astype('float64')
    df['Importe'] = df['Importe'].astype('float64')
    df['Precio medio'] = df['Precio medio'].astype('float64')
    df['Codigo Cliente'] = df['Codigo Cliente'].astype('object')
    df['Serie Factura'] = df['Serie Factura'].astype('object')
    df['Codigo Comercial'] = df['Codigo Comercial'].astype('object')
    df['Empresa Emisora'] = df['Empresa Emisora'].astype('object')
    return

# %%
impcsv()

# %%
df.dtypes
# Out:
# Referencia             object
# Cantidad con signo      int64
# Entradas                int64
# Salidas                 int64
# Cantidad Abonada        int64
# Precio                float64
# Importe               float64
# Existencia              int64
# Precio medio          float64
# Escalón de precio       int64
# Codigo Cliente         object
# Codigo Factura         object
# Fecha Factura          object
# Serie Factura          object
# Codigo Comercial       object
# Empresa Emisora        object
# Nombre Tarifa          object
# dtype: object

# %%
df.head()
# Out:
#   Referencia  Cantidad con signo  Entradas  Salidas  Cantidad Abonada  Precio  \
# 0    PH 7210                  -2         0        2                 0   53.84
# 1    PH 7210                  -1         0        1                 0   56.67
# 2    PH 7210                  -4         0        4                 4   65.29
# 3    PH 7210                   4         4        0                 0   65.29
# 4    PH 7210                  -4         0        4                 0   65.29
#
#    Importe  Existencia  Precio medio  Escalón de precio Codigo Cliente  \
# 0   107.68         205         34.35                  1          20466
# 1    56.67         204         34.35                  1          48380
# 2   261.16         191         34.35                  1          66756
# 3  -261.16         191         34.35                  1          66756
# 4   261.16         191         34.35                  1          67664
#
#    Codigo Factura Fecha Factura Serie Factura Codigo Comercial  \
# ...

# %%
df.groupby('Referencia').sum().sort_values(by='Salidas',ascending=False)
# Out:
#              Cantidad con signo  Entradas  Salidas  Cantidad Abonada  \
# Referencia
# PH 7266                   -2572        50     2622                46
# PH 9408                   -1288         8     1296                 3
# PH 7288                    -988        19     1007                19
# PH 9406                    -966        22      988                18
# PH 9410                    -654         9      663                 9
# PH 7312                    -644        15      659                13
# PH 9420                    -454         9      463                 8
# PH 9210                    -418         3      421                 3
# PH 9485                    -393        14      407                11
# PH 7322                    -393         7      400                 7
# PH 9465                    -326         4      330                 4
# PH 9220                    -310        10      320                 6
# ...

# %%
# Articulos mas vendidos

ventas_art = df.groupby('Referencia')['Salidas'].sum()
ventas_art_cli = df.groupby(['Codigo Cliente', 'Referencia'])
ventas_art_cli_sum = ventas_art_cli['Salidas'].sum()

# %%
ventas_art.sort_values(ascending=False).head(10)
# Out:
# Referencia
# PH 7266    2622
# PH 9408    1296
# PH 7288    1007
# PH 9406     988
# PH 9410     663
# PH 7312     659
# PH 9420     463
# PH 9210     421
# PH 9485     407
# PH 7322     400
# Name: Salidas, dtype: int64

# %%
ventas_art_cli.sort_values(ascending=False).head(50)
# Out:
# Referencia  Codigo Cliente
# PH 7266     34760             1313
# PH 7288     34760              537
# PH 7266     40621              234
#             20466              232
# PH 9406     34760              228
# PH 9408     34760              226
# PH 7322     34760              218
# PH 7312     65276              199
# PH 9408     20466              192
# PH 7266     57805              192
# PH 9410     34760              185
# PH 9478     34760              159
# PH 7266     67797              140
# PH 7288     67797              140
# PH 9408     52836              140
# PH 9420     34760              135
# PH 9210     34760              123
# PH 9406     20466              121
# PH 7210     34760              119
# PH 9408     57160              114
# PH 9464     40621              101
# PH 9406     67433              100
# PH 7312     34760               90
# PH 9408     40621               86
# PH 9485     34760               80
# PH 9220     34760               76
# ...

# %%
ventas_art.sort_values(ascending=False)
# Out:
# Referencia
# PH 7266        2622
# PH 9408        1296
# PH 7288        1007
# PH 9406         988
# PH 9410         663
# PH 7312         659
# PH 9420         463
# PH 9210         421
# PH 9485         407
# PH 7322         400
# PH 9465         330
# PH 9220         320
# PH 7210         311
# PH 9230         244
# PH 7315         242
# PH 9464         219
# PH 9478         205
# PH 8030         143
# PH 7621         134
# PH 7521         116
# PH 9330         106
# PH 9260          78
# PH 7512          65
# PH 7530          61
# PH 8010          55
# PH 9315          54
# PH 8020          51
# PH 9100          47
# PH 7690          40
# PH 9270          38
# PH 7631          34
# PH 7610          27
# PH 9273          16
# PH 9360          13
# PH 9293          13
# PH 9301          13
# PH 9262           5
# PH 9102           5
# PH 9404           5
# PH 8032           5
# PH 9283           3
# PH 9332           3
# PH 8022           3
# PH 9268           2
# ...

# %%
ventas_art_cli.head().sort_values(by='Salidas',ascending=False)
# Out:
#      Referencia  Cantidad con signo  Entradas  Salidas  Cantidad Abonada  \
# 190     PH 7266                -128         0      128                 0
# 182     PH 7266                -128         0      128                 0
# 282     PH 7266                -128         0      128                 0
# 415     PH 7288                -128         0      128                 6
# 235     PH 7266                -112         0      112                 0
# ...         ...                 ...       ...      ...               ...
# 1672    PH 9230                   1         1        0                 0
# 3127    PH 9485                   1         1        0                 0
# 1950    PH 9293                   1         1        0                 0
# 3055    PH 9465                   2         2        0                 0
# 1477    PH 9220                   1         1        0                 0
#
#        Precio  Importe  Existencia  Precio medio  Escalón de precio  \
# ...

# %%
df.dtypes
# Out:
# Referencia             object
# Cantidad con signo      int64
# Entradas                int64
# Salidas                 int64
# Cantidad Abonada        int64
# Precio                float64
# Importe               float64
# Existencia              int64
# Precio medio          float64
# Escalón de precio       int64
# Codigo Cliente         object
# Codigo Factura         object
# Fecha Factura          object
# Serie Factura          object
# Codigo Comercial       object
# Empresa Emisora        object
# Nombre Tarifa          object
# dtype: object

# %%
df.isna().sum()
# Out:
# Referencia            0
# Cantidad con signo    0
# Entradas              0
# Salidas               0
# Cantidad Abonada      0
# Precio                0
# Importe               0
# Existencia            0
# Precio medio          0
# Escalón de precio     0
# Codigo Cliente        0
# Codigo Factura        0
# Fecha Factura         0
# Serie Factura         0
# Codigo Comercial      0
# Empresa Emisora       0
# Nombre Tarifa         0
# dtype: int64

# %%
df['Fecha Factura'] = pd.to_datetime(df['Fecha Factura'])
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\carlo\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\carlo\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df.dtypes
# Out:
# Referencia                    object
# Cantidad con signo             int64
# Entradas                       int64
# Salidas                        int64
# Cantidad Abonada               int64
# Precio                       float64
# Importe                      float64
# Existencia                     int64
# Precio medio                 float64
# Escalón de precio              int64
# Codigo Cliente                object
# Codigo Factura                object
# Fecha Factura         datetime64[ns]
# Serie Factura                 object
# Codigo Comercial              object
# Empresa Emisora               object
# Nombre Tarifa                 object
# dtype: object

# %%
df.head()
# Out:
#   Referencia  Cantidad con signo  Entradas  Salidas  Cantidad Abonada  Precio  \
# 0    PH 7210                  -2         0        2                 0   53.84
# 1    PH 7210                  -1         0        1                 0   56.67
# 2    PH 7210                  -4         0        4                 4   65.29
# 3    PH 7210                   4         4        0                 0   65.29
# 4    PH 7210                  -4         0        4                 0   65.29
#
#    Importe  Existencia  Precio medio  Escalón de precio Codigo Cliente  \
# 0   107.68         205         34.35                  1          34760
# 1    56.67         204         34.35                  1          34760
# 2   261.16         191         34.35                  1          34760
# 3  -261.16         191         34.35                  1          34760
# 4   261.16         191         34.35                  1          34760
#
#    Codigo Factura Fecha Factura Serie Factura Codigo Comercial  \
# ...

# %%
df.loc[df['Codigo Factura']=='04-M/22-00257']
# Out:
#      Referencia  Salidas  Precio  Importe  Existencia  Precio Medio  \
# 190     PH 7266      128   26.01  3329.28         844         20.05
# 1702    PH 9230        3  339.24  1017.72         181        220.32
#
#       Escalon de Precio Codigo Cliente Codigo Factura Fecha Factura  \
# 190                   3          34760  04-M/22-00257    2022-04-26
# 1702                  3          34760  04-M/22-00257    2022-04-26
#
#      Serie Factura Empresa Emisora Nombre Tarifa
# 190             18               4          NPVM
# 1702            18               4          NPVM

# %%
# Query no premite espacios en los nombres de columnas para la busqueda
df.query('Referencia == "PH 7266"')
# Out:
#     Referencia  Salidas  Precio  Importe  Existencia  Precio Medio  \
# 80     PH 7266        0   30.58   -30.58        1069         19.50
# 81     PH 7266        1   30.58    30.58        1069         19.50
# 82     PH 7266        4   34.70   138.80        1065         19.50
# 83     PH 7266        1   33.06    33.06        1006         19.50
# 84     PH 7266        1   34.70    34.70        1001         19.50
# ..         ...      ...     ...      ...         ...           ...
# 385    PH 7266       50   29.46  1473.00        1622         20.81
# 386    PH 7266        1   39.36    39.36        1621         20.81
# 387    PH 7266        1   39.36    39.36        1608         20.81
# 388    PH 7266      128   29.46  3770.88        1480         20.81
# 389    PH 7266       20   30.06   601.20        1431         20.81
#
#      Escalon de Precio Codigo Cliente  Codigo Factura Fecha Factura  \
# 80                   1          66998  09-PM/22-00002    2022-03-01
# ...

# %%
df.columns
# Out:
# Index(['Referencia', 'Cantidad con signo', 'Entradas', 'Salidas',
#        'Cantidad Abonada', 'Precio', 'Importe', 'Existencia', 'Precio medio',
#        'Escalón de precio', 'Codigo Cliente', 'Codigo Factura',
#        'Fecha Factura', 'Serie Factura', 'Codigo Comercial', 'Empresa Emisora',
#        'Nombre Tarifa'],
#       dtype='object')

# %%
# Example of dropping columns
# df.drop(['Cantidad Abonada'], axis=1)

# %%
# Esta es una manera de seleccionar columnas y hacer una copia del DataFrame antiguo
df = df[['Referencia', 
         #'Cantidad con signo', 'Entradas', 
         'Salidas',
      # 'Cantidad Abonada', 
         'Precio', 
         'Importe', 
         'Existencia', 
         'Precio medio',
       'Escalón de precio', 
         'Codigo Cliente', 
         'Codigo Factura',
       'Fecha Factura', 'Serie Factura', 
         #'Codigo Comercial', 
         'Empresa Emisora',
       'Nombre Tarifa']].copy()

# %%
df.head()
# Out:
#   Referencia  Salidas  Precio  Importe  Existencia  Precio medio  \
# 0    PH 7210        2   53.84   107.68         205         34.35
# 1    PH 7210        1   56.67    56.67         204         34.35
# 2    PH 7210        4   65.29   261.16         191         34.35
# 3    PH 7210        0   65.29  -261.16         191         34.35
# 4    PH 7210        4   65.29   261.16         191         34.35
#
#    Escalón de precio Codigo Cliente  Codigo Factura Fecha Factura  \
# 0                  1          20466   04-M/22-00015    2022-12-01
# 1                  1          48380   08-N/22-00081    2022-01-13
# 2                  1          66756  09-PM/22-00174    2022-01-27
# 3                  1          66756  09-PM/22-00184    2022-01-31
# 4                  1          67664   09-S/22-00031    2022-01-31
#
#   Serie Factura Empresa Emisora Nombre Tarifa
# 0            18               4          NPVM
# 1             1               8          NPVD
# ...

# %%
# Para renombar columnas utilizando un diccionario
df = df.rename(columns={'Precio Medio': 'Precio_Medio',
                       'Escalon de Precio': 'Escalon_Precio',
                        'Codigo Cliente':'Codigo_Cliente',
                        'Codigo Factura': 'Codigo_Factura', 
                        'Fecha Factura': 'Fecha_Factura', 
                        'Serie Factura': 'Serie_Factura', 
                        'Empresa Emisora': 'Empresa_Emisora', 
                        'Nombre Tarifa': 'Nombre_Tarifa'})

# %%
df.head()
# Out:
#   Referencia  Salidas  Precio  Importe  Existencia  Precio_Medio  \
# 0    PH 7210        2   53.84   107.68         205         34.35
# 1    PH 7210        1   56.67    56.67         204         34.35
# 2    PH 7210        4   65.29   261.16         191         34.35
# 3    PH 7210        0   65.29  -261.16         191         34.35
# 4    PH 7210        4   65.29   261.16         191         34.35
#
#    Escalon_Precio Codigo_Cliente  Codigo_Factura Fecha_Factura Serie_Factura  \
# 0               1          20466   04-M/22-00015    2022-12-01            18
# 1               1          48380   08-N/22-00081    2022-01-13             1
# 2               1          66756  09-PM/22-00174    2022-01-27            45
# 3               1          66756  09-PM/22-00184    2022-01-31            45
# 4               1          67664   09-S/22-00031    2022-01-31            38
#
#   Empresa_Emisora Nombre_Tarifa
# 0               4          NPVM
# 1               8          NPVD
# ...

# %%
df.isna().sum()
# Out:
# Referencia           0
# Salidas              0
# Precio               0
# Importe              0
# Existencia           0
# Precio Medio         0
# Escalon de Precio    0
# Codigo Cliente       0
# Codigo Factura       0
# Fecha Factura        0
# Serie Factura        0
# Empresa Emisora      0
# Nombre Tarifa        0
# dtype: int64

# %%
df.loc[df.duplicated(subset=['Codigo_Factura'])]
# Out:
#      Referencia  Salidas  Precio  Importe  Existencia  Precio_Medio  \
# 15      PH 7210        1   42.97    42.97         137         34.35
# 89      PH 7266       20   28.53   570.60         960         19.50
# 166     PH 7266        1   19.22    19.22         516         19.50
# 167     PH 7266        1   23.84    23.84         516         19.50
# 168     PH 7266        1   23.83    23.83         516         19.50
# ...         ...      ...     ...      ...         ...           ...
# 3227    PH 9485        2   64.65   129.30         595         40.08
# 3228    PH 9485        2   64.65   129.30         587         40.08
# 3229    PH 9485        1   64.65    64.65         582         40.08
# 3230    PH 9485        0   56.16   -56.16         582         40.08
# 3231    PH 9485       10   57.12   571.20         567         40.08
#
#       Escalon_Precio Codigo_Cliente Codigo_Factura Fecha_Factura  \
# 15                 1          67488  04-S/22-00004    2022-03-24
# ...

# %%
# Aqui un ejemplo de como seleccionar los que NO son duplicados utilizando el signo ~ al inicio. Y reseteamos los indices.

# df.loc[~df.duplicated(subset=['Codigo_Factura', 'Serie_Factura', 'Empresa_Emisora'])].reset_index(drop=True)

# %%
ax =df['Fecha_Factura'].value_counts()\
    .head(10)\
    .plot(kind='bar', title='Top 10 dias con mas lineas de venta')
ax.set_xlabel('Fechas')
ax.set_ylabel('Lineas de Venta')
# Out:
# Text(0, 0.5, 'Lineas de Venta')

# %%
total_factura = df.groupby('Codigo_Factura')['Importe'].sum()

# %%
total_factura
# Out:
# Codigo_Factura
# 04-M/22-00001     984.19
# 04-M/22-00002    1053.30
# 04-M/22-00005     332.60
# 04-M/22-00006    1343.19
# 04-M/22-00007     359.17
#                   ...
# 10-S/22-00005     360.00
# 10-S/22-00006      43.00
# 10-S/22-00007      46.00
# 10-S/22-00008      43.00
# 10-S/22-00009     165.00
# Name: Importe, Length: 2206, dtype: float64

# %%
num_facturas = df.groupby('Codigo_Factura')

# %%
num_facturas.count().sort_values(by='Importe',ascending=False).head(50)
# Out:
#                 Referencia  Salidas  Precio  Importe  Existencia  \
# Codigo_Factura
# 04-M/22-00204           23       23      23       23          23
# 04-N/22-00203           20       20      20       20          20
# 04-S/22-00011           19       19      19       19          19
# 04-M/22-00775           16       16      16       16          16
# 04-S/22-00013           15       15      15       15          15
# 04-S/22-00005           15       15      15       15          15
# 04-M/22-00721           14       14      14       14          14
# 04-M/22-00015           14       14      14       14          14
# 04-M/22-00899           14       14      14       14          14
# 04-M/22-00597           13       13      13       13          13
# 04-M/22-00669           13       13      13       13          13
# 04-M/22-00665           12       12      12       12          12
# 04-M/22-00197           12       12      12       12          12
# ...

# %%
total_factura.plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
total_factura.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.plot(kind='scatter', x='total_factura', y ='num_facturas')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_factura'
#
# The above exception was the direct cause of the following exception:
#
# ...
