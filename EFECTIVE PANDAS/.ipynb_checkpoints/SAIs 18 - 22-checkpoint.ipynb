# %% [markdown]
# #### Importando librerias necesarias

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/home/ubuntu/projects/codigofacilito/Pandas_ventas_sais_18-22.csv', sep=';', encoding='latin')
data
# Out:
#         Referencia                                        Descripción  \
# 0          PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...
# 1          PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...
# 2          PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...
# 3          PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...
# 4          PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...
# ...            ...                                                ...
# 12878      PH 8032  Banco para Baterías (x12 baterias de 12V-9Ah) ...
# 12879      PH 8032  Banco para Baterías solo carcasa (x12 baterias...
# 12880      PH 8032  Banco para Baterías solo carcasa (x12 baterias...
# 12881  PH 8030-RA+  S.A.I. Phasak Conqueror Recondicionado "Grado ...
# 12882  PH 7312-RA+  S.A.I. Phasak SIRIUS Recondicionado "Grado A+"...
#
#              Fecha  Salidas    Precio  \
# 0      17-Ene-2018      1.0  127.6400
# 1       5-Mar-2018      1.0  104.0000
# 2       7-Mar-2018      1.0  104.4300
# 3      12-Mar-2018      1.0  104.4300
# 4      19-Mar-2018      1.0   86.0000
# ...            ...      ...       ...
# 12878  25-Oct-2021      1.0  377.5600
# 12879  26-Jul-2022      2.0  195.0000
# 12880   8-Ago-2022      3.0  188.2000
# 12881  29-Ago-2022      1.0  249.3000
# 12882  20-Sep-2022      1.0  102.0000
#
#       Pedido de venta -> Serie, ejercicio y nº pedido  \
# 0                                    01/03-N/18-00296
# 1                                    01/03-N/18-01235
# 2                                    01/04-M/18-00166
# 3                                    01/04-M/18-00180
# 4                                    01/04-N/18-00009
# ...                                               ...
# 12878                                01/04-M/21-00930
# 12879                                01/08-N/22-02988
# 12880                                01/04-M/22-00627
# 12881                               01/09-PM/22-01462
# 12882                               01/09-PM/22-01598
#
#        Pedido de venta -> Nº pedido  \
# 0                             296.0
# 1                            1235.0
# 2                             166.0
# 3                             180.0
# 4                               9.0
# ...                             ...
# 12878                         930.0
# 12879                        2988.0
# 12880                         627.0
# 12881                        1462.0
# 12882                        1598.0
#
#        Factura de venta -> Serie de factura emitida Cliente  \
# 0                                               1.0   58291
# 1                                               1.0   15423
# 2                                              18.0   48078
# 3                                              18.0   28786
# 4                                               1.0   58281
# ...                                             ...     ...
# 12878                                          18.0   48078
# 12879                                           1.0   65615
# 12880                                          18.0   48078
# 12881                                           NaN   66756
# 12882                                          45.0   66998
#
#                           Cliente -> Nombre fiscal
# 0                                   SPANRED S.L.U.
# 1                           BELSATI SISTEMAS, S.L.
# 2                       GRUPO ELECTRO STOCKS S.L.U
# 3           COMPONENTES INFORMATICOS ASTURIAS S.L.
# 4                            GESTSAI INGENIERIA SL
# ...                                            ...
# 12878                   GRUPO ELECTRO STOCKS S.L.U
# 12879                 GIGATEK 2020 CONSULTORIA SLL
# 12880                   GRUPO ELECTRO STOCKS S.L.U
# 12881  CLIENTE FACTURA SIMPLIFICADA PC COMPONENTES
# 12882     CLIENTE FACTURA SIMPLIFICADA ALI EXPRESS
#
# [12883 rows x 10 columns]

# %%
data.dtypes
# Out:
# Referencia                                          object
# Descripción                                         object
# Fecha                                               object
# Salidas                                            float64
# Precio                                              object
# Pedido de venta -> Serie, ejercicio y nº pedido     object
# Pedido de venta -> Nº pedido                       float64
# Factura de venta -> Serie de factura emitida       float64
# Cliente                                             object
# Cliente -> Nombre fiscal                            object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12883 entries, 0 to 12882
# Data columns (total 10 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Referencia                                       12883 non-null  object
#  1   Descripción                                      12874 non-null  object
#  2   Fecha                                            12873 non-null  object
#  3   Salidas                                          12873 non-null  float64
#  4   Precio                                           12873 non-null  object
#  5   Pedido de venta -> Serie, ejercicio y nº pedido  12779 non-null  object
#  6   Pedido de venta -> Nº pedido                     12779 non-null  float64
#  7   Factura de venta -> Serie de factura emitida     12519 non-null  float64
#  8   Cliente                                          12873 non-null  object
#  9   Cliente -> Nombre fiscal                         12872 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1006.6+ KB

# %%
data.columns
# Out:
# Index(['Referencia', 'Descripción', 'Fecha', 'Salidas', 'Precio',
#        'Pedido de venta -> Serie, ejercicio y nº pedido',
#        'Pedido de venta -> Nº pedido',
#        'Factura de venta -> Serie de factura emitida', 'Cliente',
#        'Cliente -> Nombre fiscal'],
#       dtype='object')

# %%
data.rename(columns={'Cliente -> Nombre fiscal': 'nombre_cliente', }, inplace=True)
data.head()
# Out:
#   Referencia                                        Descripción        Fecha  \
# 0    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  17-Ene-2018
# 1    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...   5-Mar-2018
# 2    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...   7-Mar-2018
# 3    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  12-Mar-2018
# 4    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  19-Mar-2018
#
#    Salidas    Precio Pedido de venta -> Serie, ejercicio y nº pedido  \
# 0      1.0  127.6400                                01/03-N/18-00296
# 1      1.0  104.0000                                01/03-N/18-01235
# 2      1.0  104.4300                                01/04-M/18-00166
# 3      1.0  104.4300                                01/04-M/18-00180
# 4      1.0   86.0000                                01/04-N/18-00009
#
#    Pedido de venta -> Nº pedido  Factura de venta -> Serie de factura emitida  \
# 0                         296.0                                           1.0
# 1                        1235.0                                           1.0
# 2                         166.0                                          18.0
# 3                         180.0                                          18.0
# 4                           9.0                                           1.0
#
#   Cliente                          nombre_cliente
# 0   58291                          SPANRED S.L.U.
# 1   15423                  BELSATI SISTEMAS, S.L.
# 2   48078              GRUPO ELECTRO STOCKS S.L.U
# 3   28786  COMPONENTES INFORMATICOS ASTURIAS S.L.
# 4   58281                   GESTSAI INGENIERIA SL

# %%
data.rename(columns={'Pedido de venta -> Nº pedido': 'num_pedido', }, inplace=True)

# %%
data.rename(columns={'Pedido de venta -> Serie, ejercicio y nº pedido': 'pedido', }, inplace=True)

# %%
data.head()
# Out:
#   referencia                                        descripcion        fecha  \
# 0    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  17-Ene-2018
# 1    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...   5-Mar-2018
# 2    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...   7-Mar-2018
# 3    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  12-Mar-2018
# 4    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  19-Mar-2018
#
#    salidas    precio            pedido  num_pedido  serie_factura Cliente  \
# 0      1.0  127.6400  01/03-N/18-00296       296.0            1.0   58291
# 1      1.0  104.0000  01/03-N/18-01235      1235.0            1.0   15423
# 2      1.0  104.4300  01/04-M/18-00166       166.0           18.0   48078
# 3      1.0  104.4300  01/04-M/18-00180       180.0           18.0   28786
# 4      1.0   86.0000  01/04-N/18-00009         9.0            1.0   58281
#
#                            nombre_cliente
# 0                          SPANRED S.L.U.
# 1                  BELSATI SISTEMAS, S.L.
# 2              GRUPO ELECTRO STOCKS S.L.U
# 3  COMPONENTES INFORMATICOS ASTURIAS S.L.
# 4                   GESTSAI INGENIERIA SL

# %%
data.rename(columns={'Descripción': 'descripcion', }, inplace=True)

# %%
data.rename(columns={'Referencia': 'referencia', }, inplace=True)

# %%
data.rename(columns={'Fecha': 'fecha', }, inplace=True)

# %%
data.rename(columns={'Salidas': 'salidas', }, inplace=True)

# %%
data.rename(columns={'Precio': 'precio', }, inplace=True)

# %%
data.rename(columns={'Cliente': 'cliente', }, inplace=True)

# %%
data.isnull().any()
# Out:
# referencia        False
# descripcion        True
# fecha              True
# salidas            True
# precio             True
# pedido             True
# num_pedido         True
# serie_factura      True
# cliente            True
# nombre_cliente     True
# dtype: bool

# %%
pedidos_missing = data.isnull().sum()
pedidos_missing
# Out:
# referencia          0
# descripcion         9
# fecha              10
# salidas            10
# precio             10
# pedido            104
# num_pedido        104
# serie_factura     364
# cliente            10
# nombre_cliente     11
# dtype: int64

# %%
from dateutil.relativedelta import relativedelta

# %%
df = data.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12517 entries, 0 to 12882
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   referencia      12517 non-null  object
#  1   descripcion     12517 non-null  object
#  2   fecha           12517 non-null  object
#  3   salidas         12517 non-null  float64
#  4   precio          12517 non-null  object
#  5   pedido          12517 non-null  object
#  6   num_pedido      12517 non-null  float64
#  7   serie_factura   12517 non-null  float64
#  8   cliente         12517 non-null  object
#  9   nombre_cliente  12517 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.1+ MB

# %%
df["num_pedido"]= df["num_pedido"].astype('int64')
# Out:
# /tmp/ipykernel_231859/3988072517.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_pedido"]= df["num_pedido"].astype('int64')

# %%
df["salidas"]= df["salidas"].astype('int64')
# Out:
# /tmp/ipykernel_231859/1431132011.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["salidas"]= df["salidas"].astype('int64')

# %%
df["precio"]= df["precio"].astype('float64')
# Out:
# /tmp/ipykernel_231859/2870409620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["precio"]= df["precio"].astype('float64')

# %%
df["num_pedido"]= df["num_pedido"].astype('int64')
# Out:
# /tmp/ipykernel_231859/3988072517.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_pedido"]= df["num_pedido"].astype('int64')

# %%
df["serie_factura"]= df["serie_factura"].astype('int64')
# Out:
# /tmp/ipykernel_231859/3351570582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["serie_factura"]= df["serie_factura"].astype('int64')

# %%
df["cliente"]= df["cliente"].astype('int64')
# Out:
# /tmp/ipykernel_231859/3264482647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cliente"]= df["cliente"].astype('int64')

# %%
df.head(10)
# Out:
#   referencia                                        descripcion        fecha  \
# 0    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  17-Ene-2018
# 1    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...   5-Mar-2018
# 2    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...   7-Mar-2018
# 3    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  12-Mar-2018
# 4    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  19-Mar-2018
# 5    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  26-Mar-2018
# 6    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...   4-Abr-2018
# 7    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  16-Abr-2018
# 8    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  20-Abr-2018
# 9    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  24-May-2018
#
#    salidas  precio            pedido  num_pedido  serie_factura cliente  \
# 0        1  127.64  01/03-N/18-00296         296              1   58291
# 1        1  104.00  01/03-N/18-01235        1235              1   15423
# 2        1  104.43  01/04-M/18-00166         166             18   48078
# 3        1  104.43  01/04-M/18-00180         180             18   28786
# 4        1   86.00  01/04-N/18-00009           9              1   58281
# 5        2  127.64  01/03-N/18-01613        1613              1   59299
# 6        1  112.00  01/03-N/18-01742        1742              1   58291
# 7        2  127.64  01/03-N/18-01971        1971              1   49617
# 8        1  104.43  01/04-M/18-00290         290             18   48078
# 9        1  104.43  01/04-M/18-00385         385             18   48078
#
#                            nombre_cliente
# 0                          SPANRED S.L.U.
# 1                  BELSATI SISTEMAS, S.L.
# 2              GRUPO ELECTRO STOCKS S.L.U
# 3  COMPONENTES INFORMATICOS ASTURIAS S.L.
# 4                   GESTSAI INGENIERIA SL
# 5     SHOTIS SERVICIOS TECNOLÓGICOS, S.L.
# 6                          SPANRED S.L.U.
# 7                            TELPLAY S.L.
# 8              GRUPO ELECTRO STOCKS S.L.U
# 9              GRUPO ELECTRO STOCKS S.L.U

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12517 entries, 0 to 12882
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   referencia      12517 non-null  object
#  1   descripcion     12517 non-null  object
#  2   fecha           12517 non-null  object
#  3   salidas         12517 non-null  int64
#  4   precio          12517 non-null  float64
#  5   pedido          12517 non-null  object
#  6   num_pedido      12517 non-null  int64
#  7   serie_factura   12517 non-null  int64
#  8   cliente         12517 non-null  int64
#  9   nombre_cliente  12517 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 1.1+ MB

# %%
df.head(20)
# Out:
#    Referencia                                        Descripción        Fecha  \
# 0     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  17-Ene-2018
# 1     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...   5-Mar-2018
# 2     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...   7-Mar-2018
# 3     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  12-Mar-2018
# 4     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  19-Mar-2018
# 5     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  26-Mar-2018
# 6     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...   4-Abr-2018
# 7     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  16-Abr-2018
# 8     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  20-Abr-2018
# 9     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  24-May-2018
# 10    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  25-May-2018
# 11    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  20-Jun-2018
# 12    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  10-Jul-2018
# 13    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  10-Jul-2018
# 14    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  16-Jul-2018
# 15    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  30-Jul-2018
# 16    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  30-Jul-2018
# 17    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  30-Jul-2018
# 18    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  30-Jul-2018
# 19    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent...  30-Jul-2018
#
#     Salidas  Precio            pedido  num_pedido  serie_factura  Cliente  \
# 0         1  127.64  01/03-N/18-00296         296              1    58291
# 1         1  104.00  01/03-N/18-01235        1235              1    15423
# 2         1  104.43  01/04-M/18-00166         166             18    48078
# 3         1  104.43  01/04-M/18-00180         180             18    28786
# 4         1   86.00  01/04-N/18-00009           9              1    58281
# 5         2  127.64  01/03-N/18-01613        1613              1    59299
# 6         1  112.00  01/03-N/18-01742        1742              1    58291
# 7         2  127.64  01/03-N/18-01971        1971              1    49617
# 8         1  104.43  01/04-M/18-00290         290             18    48078
# 9         1  104.43  01/04-M/18-00385         385             18    48078
# 10        1  114.88  01/03-N/18-02658        2658              1    48722
# 11        1  127.64  01/03-N/18-03125        3125              1    14996
# 12        1  127.64  01/03-N/18-03152        3152              1    24645
# 13        1  127.64  01/04-M/18-00496         496             18    58281
# 14        2  104.43  01/04-M/18-00547         547             18    48078
# 15        1  104.43  01/04-M/18-00584         584             18    48078
# 16        4  104.43  01/04-M/18-00580         580             18    48078
# 17        1  104.43  01/04-M/18-00581         581             18    48078
# 18        1  104.43  01/04-M/18-00582         582             18    48078
# 19        1  104.43  01/04-M/18-00583         583             18    48078
#
#                             nombre_cliente
# 0                           SPANRED S.L.U.
# 1                   BELSATI SISTEMAS, S.L.
# 2               GRUPO ELECTRO STOCKS S.L.U
# 3   COMPONENTES INFORMATICOS ASTURIAS S.L.
# 4                    GESTSAI INGENIERIA SL
# 5      SHOTIS SERVICIOS TECNOLÓGICOS, S.L.
# 6                           SPANRED S.L.U.
# 7                             TELPLAY S.L.
# 8               GRUPO ELECTRO STOCKS S.L.U
# 9               GRUPO ELECTRO STOCKS S.L.U
# 10      BITLAN ASESORES INFORMATICOS, C.B.
# 11                  SYSCEL SOLUTIONS, S.L.
# 12       INTERNATIONAL DATA COMPUTER, S.L.
# 13                   GESTSAI INGENIERIA SL
# 14              GRUPO ELECTRO STOCKS S.L.U
# 15              GRUPO ELECTRO STOCKS S.L.U
# 16              GRUPO ELECTRO STOCKS S.L.U
# 17              GRUPO ELECTRO STOCKS S.L.U
# 18              GRUPO ELECTRO STOCKS S.L.U
# 19              GRUPO ELECTRO STOCKS S.L.U

# %%
df['fecha'] = df['fecha'].str.replace('Ene','Jan')
# Out:
# /tmp/ipykernel_231859/1563049663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fecha'] = df['fecha'].str.replace('Ene','Jan')

# %%
df['fecha'] = df['fecha'].str.replace('Abr','Apr')
# Out:
# /tmp/ipykernel_231859/3487459887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fecha'] = df['fecha'].str.replace('Abr','Apr')

# %%
df['fecha'] = df['fecha'].str.replace('Ago','Aug')
# Out:
# /tmp/ipykernel_231859/2159912137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fecha'] = df['fecha'].str.replace('Ago','Aug')

# %%
df['fecha'] = df['fecha'].str.replace('Dic','Dec')
# Out:
# /tmp/ipykernel_231859/1678617602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fecha'] = df['fecha'].str.replace('Dic','Dec')

# %%
df['fecha'] = pd.to_datetime(df['fecha'], format='%d-%b-%Y')
# Out:
# /tmp/ipykernel_231859/1122863938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fecha'] = pd.to_datetime(df['fecha'], format='%d-%b-%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12517 entries, 0 to 12882
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   referencia      12517 non-null  object
#  1   descripcion     12517 non-null  object
#  2   fecha           12517 non-null  datetime64[ns]
#  3   salidas         12517 non-null  int64
#  4   precio          12517 non-null  float64
#  5   pedido          12517 non-null  object
#  6   num_pedido      12517 non-null  int64
#  7   serie_factura   12517 non-null  int64
#  8   cliente         12517 non-null  int64
#  9   nombre_cliente  12517 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 1.1+ MB

# %%
df.head(20)
# Out:
#    referencia                                        descripcion      fecha  \
# 0     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-01-17
# 1     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-03-05
# 2     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-03-07
# 3     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-03-12
# 4     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-03-19
# 5     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-03-26
# 6     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-04-04
# 7     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-04-16
# 8     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-04-20
# 9     PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-05-24
# 10    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-05-25
# 11    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-06-20
# 12    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-07-10
# 13    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-07-10
# 14    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-07-16
# 15    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-07-30
# 16    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-07-30
# 17    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-07-30
# 18    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-07-30
# 19    PH 9100  Modulo SNMP para S.A.I. Phasak con Intelligent... 2018-07-30
#
#     salidas  precio            pedido  num_pedido  serie_factura  cliente  \
# 0         1  127.64  01/03-N/18-00296         296              1    58291
# 1         1  104.00  01/03-N/18-01235        1235              1    15423
# 2         1  104.43  01/04-M/18-00166         166             18    48078
# 3         1  104.43  01/04-M/18-00180         180             18    28786
# 4         1   86.00  01/04-N/18-00009           9              1    58281
# 5         2  127.64  01/03-N/18-01613        1613              1    59299
# 6         1  112.00  01/03-N/18-01742        1742              1    58291
# 7         2  127.64  01/03-N/18-01971        1971              1    49617
# 8         1  104.43  01/04-M/18-00290         290             18    48078
# 9         1  104.43  01/04-M/18-00385         385             18    48078
# 10        1  114.88  01/03-N/18-02658        2658              1    48722
# 11        1  127.64  01/03-N/18-03125        3125              1    14996
# 12        1  127.64  01/03-N/18-03152        3152              1    24645
# 13        1  127.64  01/04-M/18-00496         496             18    58281
# 14        2  104.43  01/04-M/18-00547         547             18    48078
# 15        1  104.43  01/04-M/18-00584         584             18    48078
# 16        4  104.43  01/04-M/18-00580         580             18    48078
# 17        1  104.43  01/04-M/18-00581         581             18    48078
# 18        1  104.43  01/04-M/18-00582         582             18    48078
# 19        1  104.43  01/04-M/18-00583         583             18    48078
#
#                             nombre_cliente
# 0                           SPANRED S.L.U.
# 1                   BELSATI SISTEMAS, S.L.
# 2               GRUPO ELECTRO STOCKS S.L.U
# 3   COMPONENTES INFORMATICOS ASTURIAS S.L.
# 4                    GESTSAI INGENIERIA SL
# 5      SHOTIS SERVICIOS TECNOLÓGICOS, S.L.
# 6                           SPANRED S.L.U.
# 7                             TELPLAY S.L.
# 8               GRUPO ELECTRO STOCKS S.L.U
# 9               GRUPO ELECTRO STOCKS S.L.U
# 10      BITLAN ASESORES INFORMATICOS, C.B.
# 11                  SYSCEL SOLUTIONS, S.L.
# 12       INTERNATIONAL DATA COMPUTER, S.L.
# 13                   GESTSAI INGENIERIA SL
# 14              GRUPO ELECTRO STOCKS S.L.U
# 15              GRUPO ELECTRO STOCKS S.L.U
# 16              GRUPO ELECTRO STOCKS S.L.U
# 17              GRUPO ELECTRO STOCKS S.L.U
# 18              GRUPO ELECTRO STOCKS S.L.U
# 19              GRUPO ELECTRO STOCKS S.L.U
